# %% [markdown]
# Testing Your Code

# %%
assert sum([1, 2, 3]) == 6, "Should be 6"

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    print("Everything passed")
# Out:
# Everything passed

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    test_sum_tuple()
    print("Everything passed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 9
#       7 if __name__ == "__main__":
#       8     test_sum()
# ----> 9     test_sum_tuple()
#      10     print("Everything passed")
#
# Cell In[14], line 5, in test_sum_tuple()
#       4 def test_sum_tuple():
# ----> 5     assert sum((1, 2, 2)) == 6, "Should be 6"
#
# AssertionError: Should be 6

# %%
import unittest


class TestSum(unittest.TestCase):

    def test_sum(self):
        self.assertEqual(sum([1, 2, 3]), 6, "Should be 6")

    def test_sum_tuple(self):
        self.assertEqual(sum((1, 2, 2)), 6, "Should be 6")

if __name__ == '__main__':
    unittest.main()
# Out:
# E
# ...
# ERROR: C:\Users\steez\AppData\Roaming\jupyter\runtime\kernel-0c832b34-eda2-424b-8a04-19ef5777faba (unittest.loader._FailedTest.C:\Users\steez\AppData\Roaming\jupyter\runtime\kernel-0c832b34-eda2-424b-8a04-19ef5777faba)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute 'C:\Users\steez\AppData\Roaming\jupyter\runtime\kernel-0c832b34-eda2-424b-8a04-19ef5777faba'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# C:\Users\steez\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

# %% [markdown]
# Writing Your First Test

# %% [markdown]
# ![Screenshot (106).png](attachment:8f9cc6d4-42e7-4853-a908-1066002194fe.png)![Screenshot (107).png](attachment:966a94d5-e67b-4a37-a7b8-364c4aa6d29d.png)

# %%
import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

if __name__ == '__main__':
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 3
#       1 import unittest
# ----> 3 from my_sum import sum
#       6 class TestSum(unittest.TestCase):
#       7     def test_list_int(self):
#
# ModuleNotFoundError: No module named 'my_sum'

# %% [markdown]
# Executing Your First Test

# %%
from fractions import Fraction

import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

    def test_list_fraction(self):
        """
        Test that it can sum a list of fractions
        """
        data = [Fraction(1, 4), Fraction(1, 4), Fraction(2, 5)]
        result = sum(data)
        self.assertEqual(result, 1)

if __name__ == '__main__':
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 5
#       1 from fractions import Fraction
#       3 import unittest
# ----> 5 from my_sum import sum
#       8 class TestSum(unittest.TestCase):
#       9     def test_list_int(self):
#
# ModuleNotFoundError: No module named 'my_sum'

# %% [markdown]
# At the end of the notebook, describe the test results in your own words.  What do the test results mean?
#
# The testing is confusing until you realize that it's easier when you set the variables based on the output. For example, if there's a program that takes 2 inputed numbers and based off those numbers, the program prints whether the number is odd or even. Testing that program means that you get rid of the input choice and set the numbers yourself.
